# %% [markdown]
# # Notebook LSTM model
#
# This notebook shows the implementation of an LSTM-RNN model for the forecasting of the price fluctuation of the meme coins: SHIBA, DOGE, and MONA.

# %%
# Import all modules needed
import math
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import cv2
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
# Load the datasets
df_shib = pd.read_csv('C:/Users/deann/Documents/University/Thesis/Thesis_git/datasets/SHIB_data.csv')
df_doge = pd.read_csv('C:/Users/deann/Documents/University/Thesis/Thesis_git/datasets/DOGE_data.csv')
df_mona = pd.read_csv('C:/Users/deann/Documents/University/Thesis/Thesis_git/datasets/MONA_data.csv')

# %%
# Function for creating percentage change
def create_perc_change(data, steps):
    y_perc_change = []
    data_len = data.shape[0]
    for i in range(steps, data_len):
        if data[i-steps, 0] == 0:
            y_perc_change.append(0)
        else:
            perc_change = ((data[i, 0] - data[i-steps, 0])/data[i-steps, 0])
            y_perc_change.append(perc_change)
    y_perc_change = np.array(y_perc_change)
    return y_perc_change

# %%
# Function for baseline RMSE (calculated between the present day and and test day which is the present day but shifted one day in advance)
def baseline(df):
    y = create_perc_change(df, 1)
    y = np.reshape(y,(y.size, 1))
    training_data_len = math.ceil(len(df)* 0.85)
    baseline_y_test = y[training_data_len:]
    baseline_y_true = y[training_data_len-1:-1]
    baseline_rmse = np.sqrt(np.mean(baseline_y_test - baseline_y_true)**2)
    return baseline_rmse

# %%
def model(path, n_lookback, n_forecast, coin, com):
    # Load dataset
    df_pre = pd.read_csv(path)

    # Without compound
    if com == 'without':
        # Feature selection
        df = df_pre[['Close', 'Open', 'High', 'Low', 'Adj Close']].to_numpy()

        # Create percentage array
        y = create_perc_change(df, n_lookback)
        y = np.reshape(y,(y.size, 1))
        
        # Scale the data for normalization
        scaler = MinMaxScaler(feature_range=(-1,1))
        scaler2 = MinMaxScaler(feature_range=(0,1))

        # Remove the first n_lookback days 
        df = df[n_lookback:]
        df_scaled = scaler.fit_transform(df)

        # Length of training data
        training_data_len = math.ceil(len(df_scaled)* 0.85)

        # Create X and Y sets by looking n_lookback days in the past and n_forecast days in the future
        X, Y = [], []
        for i in range(n_lookback, len(y) - n_forecast + 1):
            X.append(df_scaled[i - n_lookback: i])
            Y.append(y[i: i + n_forecast])
        X, Y = np.array(X), np.array(Y)
        Y_reshaped = np.reshape(Y, (Y.shape[0], Y.shape[1]))
        Y_scaled = scaler2.fit_transform(Y_reshaped)

        # Create training and test sets
        X_train, y_train = X[:training_data_len], Y_scaled[:training_data_len]
        X_test, y_test = X[training_data_len:], Y_scaled[training_data_len:]
    
        # LSTM Model
        model = keras.Sequential()
        model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1],5)))
        model.add(Dropout(0.1))
        model.add(LSTM(64, return_sequences=True))
        model.add(Dropout(0.1))
        model.add(LSTM(64, return_sequences=True))
        model.add(Dropout(0.1))
        model.add(LSTM(128, return_sequences=False))
        model.add(Dropout(0.1))
        model.add(Dense(n_forecast))#change
        model.compile(optimizer='adam', loss='mean_squared_error')
        epochs = 30
        history = model.fit(X_train, y_train, batch_size= 16, epochs=epochs, validation_data=(X_test, y_test), verbose=0)

        # Plot training and validation loss
        '''
        loss_train = np.array(history.history['loss'])
        es = np.array([x for x in range(1, epochs+1)])
        loss_val = history.history['val_loss']
        plt.plot(es, loss_train, 'g', label='Training loss')
        plt.plot(es, loss_val, 'b', label='validation loss')
        plt.title(f'Training and Validation loss with {n_lookback} days Lookback and {n_forecast} days Forecast')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()
        '''

        # Predictions using the model
        preds = model.predict(X_test)

        # Unscale the data
        pred_unscaled = scaler2.inverse_transform(preds)
        y_test_unscaled = scaler2.inverse_transform(y_test)

        # Calculate the RMSE value using the predicted values and the test values
        rmse_without = np.sqrt(np.mean(pred_unscaled - y_test_unscaled)**2)

        print(f'RSME of {coin} without compound, lookback={n_lookback} and forecast={n_forecast} is {rmse_without}')
        return rmse_without

    # With compound
    if com == 'with':
        # Feature selection
        df = df_pre[['Close', 'Open', 'High', 'Low', 'Adj Close', 'com']].to_numpy()

        # Create percentage array
        y = create_perc_change(df, n_lookback)
        y = np.reshape(y,(y.size, 1))

        # Scale the data for normalization
        scaler = MinMaxScaler(feature_range=(-1,1))
        scaler2 = MinMaxScaler(feature_range=(0,1))

        # Remove the first n_lookback days 
        df = df[n_lookback:]
        df_scaled = scaler.fit_transform(df)

        # Length of training data
        training_data_len = math.ceil(len(df_scaled)* 0.85)

        # Create X and Y sets by looking n_lookback days in the past and n_forecast days in the future
        X = []
        Y = []
        for i in range(n_lookback, len(y) - n_forecast + 1):
            X.append(df_scaled[i - n_lookback: i])
            Y.append(y[i: i + n_forecast])
        X, Y = np.array(X), np.array(Y)
        Y_reshaped = np.reshape(Y, (Y.shape[0], Y.shape[1]))
        Y_scaled = scaler2.fit_transform(Y_reshaped)

        # Create training and test sets
        X_train, y_train = X[:training_data_len], Y_scaled[:training_data_len]
        X_test, y_test = X[training_data_len:], Y_scaled[training_data_len:]
    
        #LSTM Model
        print('Start lstm')
        model = keras.Sequential()
        model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1],6)))
        model.add(Dropout(0.1))
        model.add(LSTM(64, return_sequences=True))
        model.add(Dropout(0.1))
        model.add(LSTM(64, return_sequences=True))
        model.add(Dropout(0.1))
        model.add(LSTM(128, return_sequences=False))
        model.add(Dropout(0.1))
        model.add(Dense(n_forecast))#change
        model.compile(optimizer='adam', loss='mean_squared_error')
        epochs = 30
        history = model.fit(X_train, y_train, batch_size= 16, epochs=epochs, validation_data=(X_test, y_test), verbose=0)

        # Plot training and validation loss
        '''
        loss_train = np.array(history.history['loss'])
        es = np.array([x for x in range(1, epochs+1)])
        loss_val = history.history['val_loss']
        plt.plot(es, loss_train, 'g', label='Training loss')
        plt.plot(es, loss_val, 'b', label='validation loss')
        plt.title(f'Training and Validation loss with {n_lookback} days Lookback and {n_forecast} days Forecast')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()
        '''

        # Predictions using the model
        preds = model.predict(X_test)

        # Unscale the data
        pred_unscaled = scaler2.inverse_transform(preds)
        y_test_unscaled = scaler2.inverse_transform(y_test)

        # Calculate the RMSE value using the predicted values and the test values
        rmse_with = np.sqrt(np.mean(pred_unscaled - y_test_unscaled)**2)

        print(f'RSME of {coin} with compound, lookback={n_lookback} and forecast={n_forecast} is {rmse_with}')
        return rmse_with
    else:
        print('Type with or without')
    
    return

# %% [markdown]
# ### Run models for the coins with and without compound value

# %%
# Function for running the models
def run_models(path, name):
    n_days = [1, 7, 14, 30]
    df_rmse = pd.DataFrame({})
    for com in ['with', 'without']:
        for lookback in n_days:
            vals = []
            for forecast in n_days:
                rmse_value = model(path, lookback, forecast, name, com)
                vals.append(rmse_value)
            df_rmse[f'lookback {lookback}'] = np.array(vals)
        df_rmse.to_csv(f'{name}_{com}.csv')
    return df_rmse

# %%
# DOGE
doge = run_models('C:/Users/deann/Documents/University/Thesis/Thesis_git/datasets/DOGE_data.csv', 'DOGE')

# SHIB
shib = run_models('C:/Users/deann/Documents/University/Thesis/Thesis_git/datasets/SHIB_data.csv', 'SHIB')

# MONA
mona = run_models('C:/Users/deann/Documents/University/Thesis/Thesis_git/datasets/MONA_data.csv', 'MONA')
# Out:
# Start lstm
# Epoch 1/30
# 45/45 [==============================] - 9s 39ms/step - loss: 0.0035 - val_loss: 3.5328e-04
# Epoch 2/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7955e-04
# Epoch 3/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7838e-04
# Epoch 4/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 3.6278e-04
# Epoch 5/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.8000e-04
# Epoch 6/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7910e-04
# Epoch 7/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7690e-04
# Epoch 8/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7847e-04
# Epoch 9/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7685e-04
# Epoch 10/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 3.1752e-04
# Epoch 11/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.9459e-04
# Epoch 12/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.8273e-04
# Epoch 13/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7721e-04
# Epoch 14/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.7722e-04
# Epoch 15/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 3.0006e-04
# Epoch 16/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.9480e-04
# Epoch 17/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 4.1828e-04
# Epoch 18/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 2.9432e-04
# Epoch 19/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 3.9767e-04
# Epoch 20/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.8099e-04
# Epoch 21/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7948e-04
# Epoch 22/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7788e-04
# Epoch 23/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8013e-04
# Epoch 24/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7825e-04
# Epoch 25/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8726e-04
# Epoch 26/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8188e-04
# Epoch 27/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7872e-04
# Epoch 28/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 4.6731e-04
# Epoch 29/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8297e-04
# Epoch 30/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 3.4990e-04
# 4/4 [==============================] - 2s 3ms/step
# RSME of DOGE with compound, lookback=1 and forecast=1 is 0.033531852118672476
# Start lstm
# Epoch 1/30
# 45/45 [==============================] - 8s 42ms/step - loss: 0.0046 - val_loss: 3.1253e-04
# Epoch 2/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.9290e-04
# Epoch 3/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.9593e-04
# Epoch 4/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.0171e-04
# Epoch 5/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.3605e-04
# Epoch 6/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1938e-04
# Epoch 7/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 3.3014e-04
# Epoch 8/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1593e-04
# Epoch 9/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1025e-04
# Epoch 10/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.0419e-04
# Epoch 11/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9982e-04
# Epoch 12/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.0480e-04
# Epoch 13/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 3.2845e-04
# Epoch 14/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1879e-04
# Epoch 15/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9208e-04
# Epoch 16/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.0417e-04
# Epoch 17/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9965e-04
# Epoch 18/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1569e-04
# Epoch 19/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9375e-04
# Epoch 20/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.0776e-04
# Epoch 21/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.4287e-04
# Epoch 22/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9235e-04
# Epoch 23/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9363e-04
# Epoch 24/30
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0017 - val_loss: 2.9611e-04
# Epoch 25/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.2318e-04
# Epoch 26/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 3.0978e-04
# Epoch 27/30
# 45/45 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 3.1892e-04
# Epoch 28/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 2.8951e-04
# Epoch 29/30
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0017 - val_loss: 2.9981e-04
# Epoch 30/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 2.9617e-04
# 4/4 [==============================] - 2s 4ms/step
# RSME of DOGE with compound, lookback=1 and forecast=7 is 0.0005408629474084816
# Start lstm
# Epoch 1/30
# 45/45 [==============================] - 9s 43ms/step - loss: 0.0051 - val_loss: 2.9769e-04
# Epoch 2/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.7837e-04
# Epoch 3/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.8714e-04
# Epoch 4/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9075e-04
# Epoch 5/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9904e-04
# Epoch 6/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9758e-04
# Epoch 7/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7813e-04
# Epoch 8/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8763e-04
# Epoch 9/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9537e-04
# Epoch 10/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8878e-04
# Epoch 11/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8187e-04
# Epoch 12/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1301e-04
# Epoch 13/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9289e-04
# Epoch 14/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7950e-04
# Epoch 15/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7891e-04
# Epoch 16/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8184e-04
# Epoch 17/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8199e-04
# Epoch 18/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9549e-04
# Epoch 19/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7850e-04
# Epoch 20/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.1410e-04
# Epoch 21/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8846e-04
# Epoch 22/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8717e-04
# Epoch 23/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7760e-04
# Epoch 24/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.7793e-04
# Epoch 25/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8111e-04
# Epoch 26/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 3.0049e-04
# Epoch 27/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8008e-04
# Epoch 28/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9539e-04
# Epoch 29/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.9339e-04
# Epoch 30/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.8210e-04
# 4/4 [==============================] - 2s 3ms/step
# RSME of DOGE with compound, lookback=1 and forecast=14 is 0.0013704514034036455
# Start lstm
# Epoch 1/30
# 45/45 [==============================] - 10s 42ms/step - loss: 0.0055 - val_loss: 2.3168e-04
# Epoch 2/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.3225e-04
# Epoch 3/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.3108e-04
# Epoch 4/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.3723e-04
# Epoch 5/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.4345e-04
# Epoch 6/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.4157e-04
# Epoch 7/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.3996e-04
# Epoch 8/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3840e-04
# Epoch 9/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 2.2912e-04
# Epoch 10/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3283e-04
# Epoch 11/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.5522e-04
# Epoch 12/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2931e-04
# Epoch 13/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3031e-04
# Epoch 14/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3210e-04
# Epoch 15/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2815e-04
# Epoch 16/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2959e-04
# Epoch 17/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.4112e-04
# Epoch 18/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3505e-04
# Epoch 19/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2886e-04
# Epoch 20/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2798e-04
# Epoch 21/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3403e-04
# Epoch 22/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2908e-04
# Epoch 23/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3976e-04
# Epoch 24/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.3812e-04
# Epoch 25/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3611e-04
# Epoch 26/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 2.3246e-04
# Epoch 27/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.3508e-04
# Epoch 28/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.4438e-04
# Epoch 29/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.2508e-04
# Epoch 30/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 2.4366e-04
# 3/3 [==============================] - 2s 4ms/step
# RSME of DOGE with compound, lookback=1 and forecast=30 is 0.016190569323194976
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 58ms/step - loss: 0.0104 - val_loss: 0.0023
# Epoch 2/30
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0028
# Epoch 3/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0094 - val_loss: 0.0027
# Epoch 4/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0094 - val_loss: 0.0023
# Epoch 5/30
# 44/44 [==============================] - 1s 27ms/step - loss: 0.0093 - val_loss: 0.0022
# Epoch 6/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0093 - val_loss: 0.0026
# Epoch 7/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0092 - val_loss: 0.0028
# Epoch 8/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0095 - val_loss: 0.0024
# Epoch 9/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0092 - val_loss: 0.0025
# Epoch 10/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0096 - val_loss: 0.0023
# Epoch 11/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0094 - val_loss: 0.0025
# Epoch 12/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0093 - val_loss: 0.0047
# Epoch 13/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0092 - val_loss: 0.0031
# Epoch 14/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0038
# Epoch 15/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0022
# Epoch 16/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0088 - val_loss: 0.0020
# Epoch 17/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0021
# Epoch 18/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0021
# Epoch 19/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0084 - val_loss: 0.0019
# Epoch 20/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0081 - val_loss: 0.0028
# Epoch 21/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0082 - val_loss: 0.0025
# Epoch 22/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0084 - val_loss: 0.0017
# Epoch 23/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0070 - val_loss: 0.0037
# Epoch 24/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0086 - val_loss: 0.0020
# Epoch 25/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0073 - val_loss: 0.0027
# Epoch 26/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0076 - val_loss: 0.0015
# Epoch 27/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 28/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0080 - val_loss: 0.0022
# Epoch 29/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0084 - val_loss: 0.0020
# Epoch 30/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0078 - val_loss: 0.0017
# 4/4 [==============================] - 2s 6ms/step
# RSME of DOGE with compound, lookback=7 and forecast=1 is 0.03547268957126617
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 57ms/step - loss: 0.0104 - val_loss: 0.0023
# Epoch 2/30
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 3/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0094 - val_loss: 0.0023
# Epoch 4/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0094 - val_loss: 0.0024
# Epoch 5/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0095 - val_loss: 0.0022
# Epoch 6/30
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0095 - val_loss: 0.0025
# Epoch 7/30
# 44/44 [==============================] - 1s 29ms/step - loss: 0.0093 - val_loss: 0.0027
# Epoch 8/30
# 44/44 [==============================] - 1s 27ms/step - loss: 0.0092 - val_loss: 0.0028
# Epoch 9/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0094 - val_loss: 0.0026
# Epoch 10/30
# 44/44 [==============================] - 1s 29ms/step - loss: 0.0094 - val_loss: 0.0023
# Epoch 11/30
# 44/44 [==============================] - 1s 33ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 12/30
# 44/44 [==============================] - 1s 27ms/step - loss: 0.0092 - val_loss: 0.0030
# Epoch 13/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0092 - val_loss: 0.0025
# Epoch 14/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0092 - val_loss: 0.0026
# Epoch 15/30
# 44/44 [==============================] - 1s 27ms/step - loss: 0.0092 - val_loss: 0.0026
# Epoch 16/30
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0092 - val_loss: 0.0023
# Epoch 17/30
# 44/44 [==============================] - 1s 30ms/step - loss: 0.0092 - val_loss: 0.0024
# Epoch 18/30
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0093 - val_loss: 0.0035
# Epoch 19/30
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0092 - val_loss: 0.0023
# Epoch 20/30
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0093 - val_loss: 0.0026
# Epoch 21/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0093 - val_loss: 0.0024
# Epoch 22/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0023
# Epoch 23/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0024
# Epoch 24/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0091 - val_loss: 0.0024
# Epoch 25/30
# 44/44 [==============================] - 1s 27ms/step - loss: 0.0091 - val_loss: 0.0022
# Epoch 26/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0091 - val_loss: 0.0033
# Epoch 27/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0027
# Epoch 28/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0023
# Epoch 29/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 30/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0089 - val_loss: 0.0023
# 4/4 [==============================] - 2s 6ms/step
# RSME of DOGE with compound, lookback=7 and forecast=7 is 0.010231225542329905
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 10s 59ms/step - loss: 0.0106 - val_loss: 0.0027
# Epoch 2/30
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0094 - val_loss: 0.0026
# Epoch 3/30
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0093 - val_loss: 0.0038
# Epoch 4/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0095 - val_loss: 0.0024
# Epoch 5/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0024
# Epoch 6/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0094 - val_loss: 0.0023
# Epoch 7/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0024
# Epoch 8/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0025
# Epoch 9/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 10/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 11/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0023
# Epoch 12/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0026
# Epoch 13/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0024
# Epoch 14/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0026
# Epoch 15/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0026
# Epoch 16/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0025
# Epoch 17/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0031
# Epoch 18/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0027
# Epoch 19/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0024
# Epoch 20/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0025
# Epoch 21/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0027
# Epoch 22/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0027
# Epoch 23/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0025
# Epoch 24/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0027
# Epoch 25/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0032
# Epoch 26/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0091 - val_loss: 0.0023
# Epoch 27/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0029
# Epoch 28/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0030
# Epoch 29/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0026
# Epoch 30/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0035
# 4/4 [==============================] - 2s 6ms/step
# RSME of DOGE with compound, lookback=7 and forecast=14 is 0.18738617403409785
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 57ms/step - loss: 0.0104 - val_loss: 0.0022
# Epoch 2/30
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0094 - val_loss: 0.0018
# Epoch 3/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0018
# Epoch 4/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0021
# Epoch 5/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0022
# Epoch 6/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0019
# Epoch 7/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0025
# Epoch 8/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0020
# Epoch 9/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0022
# Epoch 10/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0017
# Epoch 11/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0092 - val_loss: 0.0027
# Epoch 12/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0023
# Epoch 13/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0090 - val_loss: 0.0020
# Epoch 14/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0028
# Epoch 15/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0017
# Epoch 16/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0027
# Epoch 17/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0028
# Epoch 18/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0018
# Epoch 19/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0022
# Epoch 20/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0017
# Epoch 21/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0021
# Epoch 22/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0090 - val_loss: 0.0020
# Epoch 23/30
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0089 - val_loss: 0.0023
# Epoch 24/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0089 - val_loss: 0.0026
# Epoch 25/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0025
# Epoch 26/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0090 - val_loss: 0.0085
# Epoch 27/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 0.0018
# Epoch 28/30
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0090 - val_loss: 0.0023
# Epoch 29/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0089 - val_loss: 0.0028
# Epoch 30/30
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0088 - val_loss: 0.0046
# 3/3 [==============================] - 2s 5ms/step
# RSME of DOGE with compound, lookback=7 and forecast=30 is 0.27565460337546543
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 72ms/step - loss: 0.0114 - val_loss: 0.0014
# Epoch 2/30
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0107 - val_loss: 0.0013
# Epoch 3/30
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0105 - val_loss: 0.0013
# Epoch 4/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0103 - val_loss: 0.0018
# Epoch 5/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0104 - val_loss: 0.0016
# Epoch 6/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0104 - val_loss: 0.0012
# Epoch 7/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0102 - val_loss: 0.0013
# Epoch 8/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0103 - val_loss: 0.0025
# Epoch 9/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0101 - val_loss: 0.0014
# Epoch 10/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0094 - val_loss: 0.0016
# Epoch 11/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0092 - val_loss: 9.1339e-04
# Epoch 12/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0095 - val_loss: 0.0011
# Epoch 13/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0091 - val_loss: 8.5836e-04
# Epoch 14/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0087 - val_loss: 0.0022
# Epoch 15/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0084 - val_loss: 0.0030
# Epoch 16/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0081 - val_loss: 5.2022e-04
# Epoch 17/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0082 - val_loss: 7.3102e-04
# Epoch 18/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0085 - val_loss: 9.4257e-04
# Epoch 19/30
# 44/44 [==============================] - 2s 41ms/step - loss: 0.0082 - val_loss: 8.3862e-04
# Epoch 20/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 21/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0090 - val_loss: 8.4589e-04
# Epoch 22/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0089 - val_loss: 0.0012
# Epoch 23/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0079 - val_loss: 0.0036
# Epoch 24/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0077 - val_loss: 0.0016
# Epoch 25/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0076 - val_loss: 3.8716e-04
# Epoch 26/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0071 - val_loss: 3.5350e-04
# Epoch 27/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0076 - val_loss: 4.2252e-04
# Epoch 28/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0066 - val_loss: 9.1491e-04
# Epoch 29/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0075 - val_loss: 4.3443e-04
# Epoch 30/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0069 - val_loss: 4.8607e-04
# 4/4 [==============================] - 2s 8ms/step
# RSME of DOGE with compound, lookback=14 and forecast=1 is 0.1335650175640427
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 72ms/step - loss: 0.0110 - val_loss: 0.0017
# Epoch 2/30
# 44/44 [==============================] - 2s 35ms/step - loss: 0.0109 - val_loss: 0.0019
# Epoch 3/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0105 - val_loss: 0.0016
# Epoch 4/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0105 - val_loss: 0.0018
# Epoch 5/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0104 - val_loss: 0.0015
# Epoch 6/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0104 - val_loss: 0.0016
# Epoch 7/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0104 - val_loss: 0.0014
# Epoch 8/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0103 - val_loss: 0.0062
# Epoch 9/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0104 - val_loss: 0.0025
# Epoch 10/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0103 - val_loss: 0.0017
# Epoch 11/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0103 - val_loss: 0.0014
# Epoch 12/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0101 - val_loss: 0.0014
# Epoch 13/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0099 - val_loss: 0.0020
# Epoch 14/30
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0096 - val_loss: 0.0020
# Epoch 15/30
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0096 - val_loss: 0.0014
# Epoch 16/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0096 - val_loss: 0.0016
# Epoch 17/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0091 - val_loss: 0.0014
# Epoch 18/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0090 - val_loss: 0.0023
# Epoch 19/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0090 - val_loss: 0.0022
# Epoch 20/30
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0087 - val_loss: 0.0012
# Epoch 21/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0087 - val_loss: 0.0011
# Epoch 22/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0085 - val_loss: 0.0023
# Epoch 23/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0083 - val_loss: 0.0020
# Epoch 24/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 25/30
# 44/44 [==============================] - 2s 41ms/step - loss: 0.0079 - val_loss: 0.0024
# Epoch 26/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 27/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0085 - val_loss: 0.0023
# Epoch 28/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 29/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0084 - val_loss: 0.0039
# Epoch 30/30
# 44/44 [==============================] - 2s 41ms/step - loss: 0.0078 - val_loss: 9.1275e-04
# 4/4 [==============================] - 3s 8ms/step
# RSME of DOGE with compound, lookback=14 and forecast=7 is 0.012065815926364496
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 72ms/step - loss: 0.0107 - val_loss: 0.0016
# Epoch 2/30
# 44/44 [==============================] - 2s 35ms/step - loss: 0.0104 - val_loss: 0.0015
# Epoch 3/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0105 - val_loss: 0.0018
# Epoch 4/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0103 - val_loss: 0.0014
# Epoch 5/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0104 - val_loss: 0.0018
# Epoch 6/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0104 - val_loss: 0.0017
# Epoch 7/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0105 - val_loss: 0.0015
# Epoch 8/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0102 - val_loss: 0.0030
# Epoch 9/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0103 - val_loss: 0.0015
# Epoch 10/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0103 - val_loss: 0.0015
# Epoch 11/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0102 - val_loss: 0.0016
# Epoch 12/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0103 - val_loss: 0.0022
# Epoch 13/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0102 - val_loss: 0.0014
# Epoch 14/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0101 - val_loss: 0.0023
# Epoch 15/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0102 - val_loss: 0.0017
# Epoch 16/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0101 - val_loss: 0.0014
# Epoch 17/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0101 - val_loss: 0.0019
# Epoch 18/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0101 - val_loss: 0.0018
# Epoch 19/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0099 - val_loss: 0.0016
# Epoch 20/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0095 - val_loss: 0.0015
# Epoch 21/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0097 - val_loss: 0.0015
# Epoch 22/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0096 - val_loss: 0.0017
# Epoch 23/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0096 - val_loss: 0.0016
# Epoch 24/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0095 - val_loss: 0.0027
# Epoch 25/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0091 - val_loss: 0.0030
# Epoch 26/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0091 - val_loss: 0.0015
# Epoch 27/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0092 - val_loss: 0.0040
# Epoch 28/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0089 - val_loss: 0.0012
# Epoch 29/30
# 44/44 [==============================] - 2s 41ms/step - loss: 0.0090 - val_loss: 0.0023
# Epoch 30/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0092 - val_loss: 0.0023
# 3/3 [==============================] - 2s 10ms/step
# RSME of DOGE with compound, lookback=14 and forecast=14 is 0.3031025583238594
# Start lstm
# Epoch 1/30
# 44/44 [==============================] - 9s 72ms/step - loss: 0.0107 - val_loss: 0.0017
# Epoch 2/30
# 44/44 [==============================] - 1s 34ms/step - loss: 0.0103 - val_loss: 0.0015
# Epoch 3/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0102 - val_loss: 0.0015
# Epoch 4/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0104 - val_loss: 0.0017
# Epoch 5/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0102 - val_loss: 0.0014
# Epoch 6/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0102 - val_loss: 0.0036
# Epoch 7/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0101 - val_loss: 0.0019
# Epoch 8/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0100 - val_loss: 0.0022
# Epoch 9/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0101 - val_loss: 0.0021
# Epoch 10/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0099 - val_loss: 0.0016
# Epoch 11/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0099 - val_loss: 0.0029
# Epoch 12/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0100 - val_loss: 0.0043
# Epoch 13/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0099 - val_loss: 0.0014
# Epoch 14/30
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0099 - val_loss: 0.0064
# Epoch 15/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0099 - val_loss: 0.0026
# Epoch 16/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0098 - val_loss: 0.0025
# Epoch 17/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0098 - val_loss: 0.0023
# Epoch 18/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0097 - val_loss: 0.0038
# Epoch 19/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0096 - val_loss: 0.0035
# Epoch 20/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0097 - val_loss: 0.0014
# Epoch 21/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0096 - val_loss: 0.0034
# Epoch 22/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0096 - val_loss: 0.0024
# Epoch 23/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0096 - val_loss: 0.0015
# Epoch 24/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0096 - val_loss: 0.0020
# Epoch 25/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0096 - val_loss: 0.0029
# Epoch 26/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0095 - val_loss: 0.0011
# Epoch 27/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0096 - val_loss: 0.0017
# Epoch 28/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0094 - val_loss: 0.0014
# Epoch 29/30
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0094 - val_loss: 0.0027
# Epoch 30/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0093 - val_loss: 0.0021
# 3/3 [==============================] - 2s 11ms/step
# RSME of DOGE with compound, lookback=14 and forecast=30 is 0.25794821445581784
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 11s 104ms/step - loss: 0.0246 - val_loss: 0.0028
# Epoch 2/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0207 - val_loss: 9.8983e-04
# Epoch 3/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0192 - val_loss: 8.9412e-04
# Epoch 4/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0195 - val_loss: 0.0146
# Epoch 5/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0164 - val_loss: 0.0021
# Epoch 6/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0154 - val_loss: 7.8999e-04
# Epoch 7/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0161 - val_loss: 0.0029
# Epoch 8/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0139 - val_loss: 0.0023
# Epoch 9/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0140 - val_loss: 0.0247
# Epoch 10/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0119 - val_loss: 7.9533e-04
# Epoch 11/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0183 - val_loss: 0.0025
# Epoch 12/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0126 - val_loss: 0.0050
# Epoch 13/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0130 - val_loss: 0.0049
# Epoch 14/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0100 - val_loss: 0.0046
# Epoch 15/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0097 - val_loss: 0.0020
# Epoch 16/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0100 - val_loss: 0.0032
# Epoch 17/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0092 - val_loss: 0.0082
# Epoch 18/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0099 - val_loss: 0.0080
# Epoch 19/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0078 - val_loss: 0.0107
# Epoch 20/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0082 - val_loss: 0.0019
# Epoch 21/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0074 - val_loss: 0.0131
# Epoch 22/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0076 - val_loss: 0.0210
# Epoch 23/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0074 - val_loss: 0.0267
# Epoch 24/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0059 - val_loss: 0.0268
# Epoch 25/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0064 - val_loss: 0.0282
# Epoch 26/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0060 - val_loss: 0.0265
# Epoch 27/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0050 - val_loss: 0.0378
# Epoch 28/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0043 - val_loss: 0.0171
# Epoch 29/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0046 - val_loss: 0.0143
# Epoch 30/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0046 - val_loss: 0.0222
# 3/3 [==============================] - 2s 17ms/step
# RSME of DOGE with compound, lookback=30 and forecast=1 is 0.5535372094728606
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 12s 108ms/step - loss: 0.0230 - val_loss: 0.0046
# Epoch 2/30
# 43/43 [==============================] - 3s 68ms/step - loss: 0.0208 - val_loss: 0.0029
# Epoch 3/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0189 - val_loss: 0.0057
# Epoch 4/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0164 - val_loss: 0.0012
# Epoch 5/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0141 - val_loss: 0.0013
# Epoch 6/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0138 - val_loss: 0.0104
# Epoch 7/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0118 - val_loss: 0.0069
# Epoch 8/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0123 - val_loss: 0.0028
# Epoch 9/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0119 - val_loss: 0.0018
# Epoch 10/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0116 - val_loss: 0.0085
# Epoch 11/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0100 - val_loss: 0.0040
# Epoch 12/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 13/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0082 - val_loss: 0.0030
# Epoch 14/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0087 - val_loss: 0.0133
# Epoch 15/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0102 - val_loss: 0.0072
# Epoch 16/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0095 - val_loss: 0.0111
# Epoch 17/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0075 - val_loss: 0.0084
# Epoch 18/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0072 - val_loss: 0.0105
# Epoch 19/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0074 - val_loss: 0.0106
# Epoch 20/30
# 43/43 [==============================] - 3s 75ms/step - loss: 0.0078 - val_loss: 0.0183
# Epoch 21/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0083 - val_loss: 0.0048
# Epoch 22/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0078 - val_loss: 0.0128
# Epoch 23/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0060 - val_loss: 0.0122
# Epoch 24/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0065 - val_loss: 0.0157
# Epoch 25/30
# 43/43 [==============================] - 4s 86ms/step - loss: 0.0062 - val_loss: 0.0241
# Epoch 26/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 27/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0062 - val_loss: 0.0166
# Epoch 28/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0054 - val_loss: 0.0164
# Epoch 29/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0049 - val_loss: 0.0194
# Epoch 30/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0050 - val_loss: 0.0176
# 3/3 [==============================] - 2s 14ms/step
# RSME of DOGE with compound, lookback=30 and forecast=7 is 0.5268905029179858
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 11s 105ms/step - loss: 0.0229 - val_loss: 0.0040
# Epoch 2/30
# 43/43 [==============================] - 3s 68ms/step - loss: 0.0227 - val_loss: 0.0055
# Epoch 3/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0206 - val_loss: 0.0023
# Epoch 4/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0200 - val_loss: 0.0085
# Epoch 5/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0170 - val_loss: 0.0023
# Epoch 6/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0153 - val_loss: 0.0080
# Epoch 7/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0135 - val_loss: 0.0033
# Epoch 8/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0118 - val_loss: 0.0081
# Epoch 9/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0110 - val_loss: 0.0012
# Epoch 10/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0111 - val_loss: 0.0036
# Epoch 11/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0101 - val_loss: 0.0088
# Epoch 12/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0100 - val_loss: 0.0022
# Epoch 13/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0096 - val_loss: 0.0018
# Epoch 14/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0095 - val_loss: 0.0160
# Epoch 15/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0096 - val_loss: 0.0033
# Epoch 16/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0093 - val_loss: 0.0120
# Epoch 17/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0086 - val_loss: 0.0017
# Epoch 18/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0091 - val_loss: 0.0043
# Epoch 19/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0076 - val_loss: 0.0027
# Epoch 20/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 21/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0079 - val_loss: 0.0052
# Epoch 22/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0070 - val_loss: 0.0094
# Epoch 23/30
# 43/43 [==============================] - 3s 76ms/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 24/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 25/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 26/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 27/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 28/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0065 - val_loss: 0.0016
# Epoch 29/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0059 - val_loss: 0.0193
# Epoch 30/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0059 - val_loss: 0.0015
# 3/3 [==============================] - 2s 17ms/step
# RSME of DOGE with compound, lookback=30 and forecast=14 is 0.2003262893233266
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 10s 105ms/step - loss: 0.0223 - val_loss: 0.0179
# Epoch 2/30
# 43/43 [==============================] - 3s 67ms/step - loss: 0.0216 - val_loss: 0.0109
# Epoch 3/30
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0206 - val_loss: 0.0026
# Epoch 4/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0187 - val_loss: 0.0024
# Epoch 5/30
# 43/43 [==============================] - 3s 69ms/step - loss: 0.0174 - val_loss: 0.0026
# Epoch 6/30
# ...
# Epoch 20/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 21/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0083 - val_loss: 0.0013
# Epoch 22/30
# 44/44 [==============================] - 2s 40ms/step - loss: 0.0080 - val_loss: 0.0012
# Epoch 23/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0077 - val_loss: 0.0011
# Epoch 24/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0075 - val_loss: 0.0012
# Epoch 25/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0073 - val_loss: 0.0013
# Epoch 26/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 27/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 28/30
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 29/30
# 44/44 [==============================] - 2s 38ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 30/30
# 44/44 [==============================] - 2s 42ms/step - loss: 0.0063 - val_loss: 0.0013
# 3/3 [==============================] - 2s 9ms/step
# RSME of MONA with compound, lookback=14 and forecast=30 is 0.012562914923885336
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 11s 110ms/step - loss: 0.0208 - val_loss: 0.0056
# Epoch 2/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0146 - val_loss: 0.0031
# Epoch 3/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0132 - val_loss: 0.0041
# Epoch 4/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0112 - val_loss: 0.0041
# Epoch 5/30
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0104 - val_loss: 0.0018
# Epoch 6/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0104 - val_loss: 0.0019
# Epoch 7/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0087 - val_loss: 0.0017
# Epoch 8/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0084 - val_loss: 0.0019
# Epoch 9/30
# 43/43 [==============================] - 3s 75ms/step - loss: 0.0078 - val_loss: 0.0018
# Epoch 10/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 11/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0061 - val_loss: 0.0033
# Epoch 12/30
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 13/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 14/30
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0057 - val_loss: 0.0023
# Epoch 15/30
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 16/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0060 - val_loss: 0.0024
# Epoch 17/30
# 43/43 [==============================] - 3s 77ms/step - loss: 0.0054 - val_loss: 0.0018
# Epoch 18/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0048 - val_loss: 0.0027
# Epoch 19/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 20/30
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 21/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 22/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 23/30
# 43/43 [==============================] - 4s 94ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 24/30
# 43/43 [==============================] - 4s 102ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 25/30
# 43/43 [==============================] - 4s 89ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 26/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 27/30
# 43/43 [==============================] - 4s 87ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 28/30
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 29/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 30/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0035 - val_loss: 0.0011
# 3/3 [==============================] - 2s 29ms/step
# RSME of MONA with compound, lookback=30 and forecast=1 is 0.009241761465916348
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 16s 144ms/step - loss: 0.0291 - val_loss: 0.0032
# Epoch 2/30
# 43/43 [==============================] - 4s 89ms/step - loss: 0.0159 - val_loss: 0.0030
# Epoch 3/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0125 - val_loss: 0.0024
# Epoch 4/30
# 43/43 [==============================] - 3s 76ms/step - loss: 0.0117 - val_loss: 0.0031
# Epoch 5/30
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0102 - val_loss: 0.0106
# Epoch 6/30
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0103 - val_loss: 0.0018
# Epoch 7/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0095 - val_loss: 0.0021
# Epoch 8/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0083 - val_loss: 0.0025
# Epoch 9/30
# 43/43 [==============================] - 4s 87ms/step - loss: 0.0082 - val_loss: 0.0044
# Epoch 10/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0087 - val_loss: 0.0038
# Epoch 11/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0086 - val_loss: 0.0023
# Epoch 12/30
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0075 - val_loss: 0.0020
# Epoch 13/30
# 43/43 [==============================] - 3s 76ms/step - loss: 0.0073 - val_loss: 0.0022
# Epoch 14/30
# 43/43 [==============================] - 3s 82ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 15/30
# 43/43 [==============================] - 4s 89ms/step - loss: 0.0076 - val_loss: 0.0020
# Epoch 16/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0068 - val_loss: 0.0022
# Epoch 17/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0064 - val_loss: 0.0038
# Epoch 18/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0071 - val_loss: 0.0016
# Epoch 19/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 20/30
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 21/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0061 - val_loss: 0.0022
# Epoch 22/30
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 23/30
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0057 - val_loss: 0.0019
# Epoch 24/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 25/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 26/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 27/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0047 - val_loss: 9.9428e-04
# Epoch 28/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 29/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 30/30
# 43/43 [==============================] - 4s 88ms/step - loss: 0.0053 - val_loss: 0.0018
# 3/3 [==============================] - 2s 32ms/step
# RSME of MONA with compound, lookback=30 and forecast=7 is 0.025760380257155758
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 11s 114ms/step - loss: 0.0234 - val_loss: 0.0039
# Epoch 2/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0139 - val_loss: 0.0020
# Epoch 3/30
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0127 - val_loss: 0.0034
# Epoch 4/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0119 - val_loss: 0.0032
# Epoch 5/30
# 43/43 [==============================] - 4s 87ms/step - loss: 0.0115 - val_loss: 0.0033
# Epoch 6/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0113 - val_loss: 0.0019
# Epoch 7/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0097 - val_loss: 0.0024
# Epoch 8/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0096 - val_loss: 0.0025
# Epoch 9/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0090 - val_loss: 0.0040
# Epoch 10/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0086 - val_loss: 0.0022
# Epoch 11/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0079 - val_loss: 0.0051
# Epoch 12/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0078 - val_loss: 0.0023
# Epoch 13/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0075 - val_loss: 0.0028
# Epoch 14/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 15/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 16/30
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 17/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0077 - val_loss: 0.0017
# Epoch 18/30
# 43/43 [==============================] - 3s 77ms/step - loss: 0.0073 - val_loss: 0.0024
# Epoch 19/30
# 43/43 [==============================] - 4s 81ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 20/30
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 21/30
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0059 - val_loss: 0.0038
# Epoch 22/30
# 43/43 [==============================] - 4s 88ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 23/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 24/30
# 43/43 [==============================] - 3s 77ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 25/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 26/30
# 43/43 [==============================] - 3s 77ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 27/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0045 - val_loss: 0.0069
# Epoch 28/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 29/30
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 30/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0040 - val_loss: 0.0017
# 3/3 [==============================] - 2s 42ms/step
# RSME of MONA with compound, lookback=30 and forecast=14 is 0.04272494491707393
# Start lstm
# Epoch 1/30
# 43/43 [==============================] - 11s 114ms/step - loss: 0.0251 - val_loss: 0.0018
# Epoch 2/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0165 - val_loss: 0.0015
# Epoch 3/30
# 43/43 [==============================] - 3s 76ms/step - loss: 0.0149 - val_loss: 0.0031
# Epoch 4/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0147 - val_loss: 0.0015
# Epoch 5/30
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0139 - val_loss: 0.0021
# Epoch 6/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0130 - val_loss: 0.0018
# Epoch 7/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0124 - val_loss: 0.0031
# Epoch 8/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0112 - val_loss: 0.0013
# Epoch 9/30
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0107 - val_loss: 0.0016
# Epoch 10/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0100 - val_loss: 0.0017
# Epoch 11/30
# 43/43 [==============================] - 4s 81ms/step - loss: 0.0094 - val_loss: 0.0015
# Epoch 12/30
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0088 - val_loss: 0.0013
# Epoch 13/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0084 - val_loss: 0.0013
# Epoch 14/30
# 43/43 [==============================] - 3s 79ms/step - loss: 0.0081 - val_loss: 0.0020
# Epoch 15/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0082 - val_loss: 0.0016
# Epoch 16/30
# 43/43 [==============================] - 3s 77ms/step - loss: 0.0081 - val_loss: 0.0018
# Epoch 17/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0075 - val_loss: 0.0030
# Epoch 18/30
# 43/43 [==============================] - 3s 80ms/step - loss: 0.0078 - val_loss: 0.0013
# Epoch 19/30
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 20/30
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0065 - val_loss: 0.0028
# Epoch 21/30
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0064 - val_loss: 0.0010
# Epoch 22/30
# 43/43 [==============================] - 11s 262ms/step - loss: 0.0058 - val_loss: 0.0070
# Epoch 23/30
# 43/43 [==============================] - 7238s 172s/step - loss: 0.0056 - val_loss: 0.0028
# Epoch 24/30
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 25/30
# 43/43 [==============================] - 4s 97ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 26/30
# 43/43 [==============================] - 4s 100ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 27/30
# 43/43 [==============================] - 4s 91ms/step - loss: 0.0046 - val_loss: 0.0081
# Epoch 28/30
# 43/43 [==============================] - 4s 92ms/step - loss: 0.0044 - val_loss: 9.6666e-04
# Epoch 29/30
# 43/43 [==============================] - 4s 89ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 30/30
# 43/43 [==============================] - 4s 94ms/step - loss: 0.0036 - val_loss: 0.0044
# 2/2 [==============================] - 4s 43ms/step
# RSME of MONA with compound, lookback=30 and forecast=30 is 0.0838596818875551
# 4/4 [==============================] - 12s 6ms/step
# RSME of MONA without compound, lookback=1 and forecast=1 is 0.005463319500894252
# 4/4 [==============================] - 2s 11ms/step
# RSME of MONA without compound, lookback=1 and forecast=7 is 0.003093945111781117
# 4/4 [==============================] - 2s 3ms/step
# RSME of MONA without compound, lookback=1 and forecast=14 is 0.008266217025559144
# 3/3 [==============================] - 2s 4ms/step
# RSME of MONA without compound, lookback=1 and forecast=30 is 0.0013965162430454752
# 4/4 [==============================] - 1s 11ms/step
# RSME of MONA without compound, lookback=7 and forecast=1 is 0.0005106532824586533
# 4/4 [==============================] - 2s 11ms/step
# RSME of MONA without compound, lookback=7 and forecast=7 is 0.004712785079799453
# 4/4 [==============================] - 2s 8ms/step
# RSME of MONA without compound, lookback=7 and forecast=14 is 0.00034613959255319995
# 3/3 [==============================] - 2s 8ms/step
# RSME of MONA without compound, lookback=7 and forecast=30 is 0.03144907357069507
# 4/4 [==============================] - 2s 17ms/step
# RSME of MONA without compound, lookback=14 and forecast=1 is 0.05370882610873158
# 4/4 [==============================] - 2s 16ms/step
# RSME of MONA without compound, lookback=14 and forecast=7 is 0.01357059827463236
# 3/3 [==============================] - 1s 20ms/step
# RSME of MONA without compound, lookback=14 and forecast=14 is 0.02107420977786056
# 3/3 [==============================] - 2s 21ms/step
# RSME of MONA without compound, lookback=14 and forecast=30 is 0.004436723668566425
# 3/3 [==============================] - 2s 37ms/step
# RSME of MONA without compound, lookback=30 and forecast=1 is 0.09260671800214317
# 3/3 [==============================] - 3s 34ms/step
# RSME of MONA without compound, lookback=30 and forecast=7 is 0.061610807869489026
# 3/3 [==============================] - 2s 29ms/step
# RSME of MONA without compound, lookback=30 and forecast=14 is 0.04890689092321642
# 2/2 [==============================] - 2s 42ms/step
# RSME of MONA without compound, lookback=30 and forecast=30 is 0.09522627917003464

# %%
def show_results():
    coins = ['DOGE', 'SHIB', 'MONA']
    com = ['with', 'without']
    for x in coins:
        for y in com:
            df = pd.read_csv(f'../datasets/{x}_{y}.csv')
            print('-----------------------------------------------------------------')
            print(x, y)
            print(df)
            
    return

# %%
# Results from personal tests
show_results()
# Out:
# -----------------------------------------------------------------
# DOGE with
#    Unnamed: 0  lookback 1  lookback 7  lookback 14  lookback 30
# 0           0    0.033532    0.035473     0.133565     0.553537
# 1           1    0.000541    0.010231     0.012066     0.526891
# 2           2    0.001370    0.187386     0.303103     0.200326
# 3           3    0.016191    0.275655     0.257948     0.582836
# -----------------------------------------------------------------
# DOGE without
#    Unnamed: 0  lookback 1  lookback 7  lookback 14  lookback 30
# 0           0    0.019396    0.010266     0.174793     0.578921
# 1           1    0.002634    0.038693     0.904174     0.632449
# 2           2    0.006331    0.058777     0.029181     0.082988
# 3           3    0.008791    0.102983     0.147216     0.955297
# -----------------------------------------------------------------
# SHIB with
#    Unnamed: 0  lookback 1  lookback 7  lookback 14  lookback 30
# 0           0    0.013127    0.417654     0.562075     0.032512
# 1           1    0.017694    0.041148     0.372428     0.112310
# 2           2    0.027020    0.102297     0.668051     0.165592
# 3           3    0.000551    0.178081     0.069781     0.274726
# -----------------------------------------------------------------
# SHIB without
#    Unnamed: 0  lookback 1  lookback 7  lookback 14  lookback 30
# 0           0    0.010075    0.124845     0.132480     0.053400
# 1           1    0.009898    0.255853     0.154682     0.187277
# 2           2    0.019586    0.077675     0.295807     0.114608
# 3           3    0.012225    0.055886     0.349145     0.005824
# -----------------------------------------------------------------
# MONA with
#    Unnamed: 0  lookback 1  lookback 7  lookback 14  lookback 30
# 0           0    0.004859    0.017901     0.021072     0.009242
# 1           1    0.003815    0.018799     0.008346     0.025760
# 2           2    0.001404    0.016357     0.014579     0.042725
# 3           3    0.001841    0.004993     0.012563     0.083860
# -----------------------------------------------------------------
# MONA without
#    Unnamed: 0  lookback 1  lookback 7  lookback 14  lookback 30
# 0           0    0.005463    0.000511     0.053709     0.092607
# 1           1    0.003094    0.004713     0.013571     0.061611
# 2           2    0.008266    0.000346     0.021074     0.048907
# 3           3    0.001397    0.031449     0.004437     0.095226
